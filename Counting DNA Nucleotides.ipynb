# %%
with open("rosalind_dna.txt", "r", encoding="utf-8") as f:
    s = f.read().replace("\n", "")

a = s.count("A")
c = s.count("C")
g = s.count("G")
t = s.count("T")

print(a, c, g, t)
# Out:
# 261 240 229 229
