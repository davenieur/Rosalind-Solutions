# %%
with open("rosalind_hamm.txt", "r", encoding="utf-8") as f:
    lines = f.read().strip().split()


dna_1 = lines[0]
dna_2 = lines[1]




print(sum(a != b for a, b in zip(dna_1, dna_2)))
# Out:
# 467
